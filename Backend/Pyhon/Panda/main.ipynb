# %%
import pandas as pd
import numpy as nb

dataframe = pd.read_csv('https://raw.githubusercontent.com/leonhgomes/Pandas/refs/heads/main/pokemon_data.csv')
display(dataframe)
# Out:
#        #                   Nome    Tipo 1    Tipo 2  Vida  Ataque  Defensa  \
# 0      1              Bulbasaur    Planta  Venenoso    45      49       49
# 1      2                Ivysaur    Planta  Venenoso    60      62       63
# 2      3               Venusaur    Planta  Venenoso    80      82       83
# 3      3  VenusaurMega Venusaur    Planta  Venenoso    80     100      123
# 4      4             Charmander      Fogo       NaN    39      52       43
# ..   ...                    ...       ...       ...   ...     ...      ...
# 795  719                Diancie     Pedra      Fada    50     100      150
# 796  719    DiancieMega Diancie     Pedra      Fada    50     160      110
# 797  720    HoopaHoopa Confined  Psiquico  Fantasma    80     110       60
# 798  720     HoopaHoopa Unbound  Psiquico   Noturno    80     160       60
# 799  721              Volcanion      Fogo      Agua    80     110      120
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# ...

# %%
display(dataframe.head(10)) #Primeiras linhas
# Out:
#    #                       Nome  Tipo 1    Tipo 2  Vida  Ataque  Defensa  \
# 0  1                  Bulbasaur  Planta  Venenoso    45      49       49
# 1  2                    Ivysaur  Planta  Venenoso    60      62       63
# 2  3                   Venusaur  Planta  Venenoso    80      82       83
# 3  3      VenusaurMega Venusaur  Planta  Venenoso    80     100      123
# 4  4                 Charmander    Fogo       NaN    39      52       43
# 5  5                 Charmeleon    Fogo       NaN    58      64       58
# 6  6                  Charizard    Fogo    Voador    78      84       78
# 7  6  CharizardMega Charizard X    Fogo    Dragao    78     130      111
# 8  6  CharizardMega Charizard Y    Fogo    Voador    78     104       78
# 9  7                   Squirtle    Agua       NaN    44      48       65
#
#    Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# 0       65       65          45        1     False
# 1       80       80          60        1     False
# ...

# %%
display(dataframe.tail(10)) #Ultimas linhas
# Out:
#        #                 Nome    Tipo 1    Tipo 2  Vida  Ataque  Defensa  \
# 790  714               Noibat    Voador    Dragao    40      30       35
# 791  715              Noivern    Voador    Dragao    85      70       80
# 792  716              Xerneas      Fada       NaN   126     131       95
# 793  717              Yveltal   Noturno    Voador   126     131       95
# 794  718     Zygarde50% Forme    Dragao     Terra   108     100      121
# 795  719              Diancie     Pedra      Fada    50     100      150
# 796  719  DiancieMega Diancie     Pedra      Fada    50     160      110
# 797  720  HoopaHoopa Confined  Psiquico  Fantasma    80     110       60
# 798  720   HoopaHoopa Unbound  Psiquico   Noturno    80     160       60
# 799  721            Volcanion      Fogo      Agua    80     110      120
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# 790       45       40          55        6     False
# 791       97       80         123        6     False
# ...

# %%
display(dataframe.sample(10)) #Aleatório
# Out:
#        #                     Nome    Tipo 1    Tipo 2  Vida  Ataque  Defensa  \
# 762  692                Clauncher      Agua       NaN    50      53       62
# 530  478                 Froslass      Gelo  Fantasma    70      80       70
# 779  709                Trevenant  Fantasma    Planta    85     110       76
# 306  282  GardevoirMega Gardevoir  Psiquico      Fada    68      85       65
# 487  439                 Mime Jr.  Psiquico      Fada    20      25       45
# 448  403                    Shinx  Electric       NaN    45      65       34
# 775  705                  Sliggoo    Dragao       NaN    68      75       53
# 452  407                 Roserade    Planta  Venenoso    60      70       65
# 392  359                    Absol   Noturno       NaN    65     130       60
# 729  661               Fletchling    Normal    Voador    45      50       43
#
#      Atq Esp  Def Esp  Velocidade  Geracao  Lendario
# 762       58       63          44        6     False
# ...

# %%
display(dataframe.shape) #Informa quantas linhas e colunas tem respectivamente
# Out:
# (800, 12)
